# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("happiness_score_dataset.csv")

# %%
data
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# ...

# %%
data.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# ...

# %%
data.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual'],
#       dtype='object')

# %%
data.columns.size
# Out:
# 12

# %%
data.index
# Out:
# RangeIndex(start=0, stop=158, step=1)

# %%
data.iloc[3:11]
# Out:
#         Country                           Region  Happiness Rank  \
# 3        Norway                   Western Europe               4
# 4        Canada                    North America               5
# 5       Finland                   Western Europe               6
# 6   Netherlands                   Western Europe               7
# 7        Sweden                   Western Europe               8
# 8   New Zealand        Australia and New Zealand               9
# 9     Australia        Australia and New Zealand              10
# 10       Israel  Middle East and Northern Africa              11
#
#     Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 3             7.522         0.03880                   1.45900  1.33095
# 4             7.427         0.03553                   1.32629  1.32261
# 5             7.406         0.03140                   1.29025  1.31826
# 6             7.378         0.02799                   1.32944  1.28017
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        158 non-null    object
#  1   Region                         158 non-null    object
#  2   Happiness Rank                 158 non-null    int64
#  3   Happiness Score                158 non-null    float64
#  4   Standard Error                 158 non-null    float64
#  5   Economy (GDP per Capita)       158 non-null    float64
#  6   Family                         158 non-null    float64
#  7   Health (Life Expectancy)       158 non-null    float64
#  8   Freedom                        158 non-null    float64
#  9   Trust (Government Corruption)  158 non-null    float64
#  10  Generosity                     158 non-null    float64
#  11  Dystopia Residual              158 non-null    float64
# ...

# %%
data2 =pd.read_csv("happiness_score_dataset.csv", index_col='Country' or 'Region')

# %%
data2
# Out:
#                                       Region  Happiness Rank  Happiness Score  \
# Country
# Switzerland                   Western Europe               1            7.587
# Iceland                       Western Europe               2            7.561
# Denmark                       Western Europe               3            7.527
# Norway                        Western Europe               4            7.522
# Canada                         North America               5            7.427
# ...                                      ...             ...              ...
# Rwanda                    Sub-Saharan Africa             154            3.465
# Benin                     Sub-Saharan Africa             155            3.340
# Syria        Middle East and Northern Africa             156            3.006
# Burundi                   Sub-Saharan Africa             157            2.905
# Togo                      Sub-Saharan Africa             158            2.839
#
# ...

# %%
data2.loc[['Denmark','Togo','Canada','Switzerland']]
# Out:
#                          Region  Happiness Rank  Happiness Score  \
# Country
# Denmark          Western Europe               3            7.527
# Togo         Sub-Saharan Africa             158            2.839
# Canada            North America               5            7.427
# Switzerland      Western Europe               1            7.587
#
#              Standard Error  Economy (GDP per Capita)   Family  \
# Country
# Denmark             0.03328                   1.32548  1.36058
# Togo                0.06727                   0.20868  0.13995
# Canada              0.03553                   1.32629  1.32261
# Switzerland         0.03411                   1.39651  1.34951
#
#              Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# Country
# Denmark                       0.87464  0.64938                        0.48357
# Togo                          0.28443  0.36453                        0.10731
# ...

# %%
data.shape
# Out:
# (158, 12)

# %%
data.describe()
# Out:
#        Happiness Rank  Happiness Score  Standard Error  \
# count      158.000000       158.000000      158.000000
# mean        79.493671         5.375734        0.047885
# std         45.754363         1.145010        0.017146
# min          1.000000         2.839000        0.018480
# 25%         40.250000         4.526000        0.037268
# 50%         79.500000         5.232500        0.043940
# 75%        118.750000         6.243750        0.052300
# max        158.000000         7.587000        0.136930
#
#        Economy (GDP per Capita)      Family  Health (Life Expectancy)  \
# count                158.000000  158.000000                158.000000
# mean                   0.846137    0.991046                  0.630259
# std                    0.403121    0.272369                  0.247078
# min                    0.000000    0.000000                  0.000000
# 25%                    0.545808    0.856823                  0.439185
# ...

# %%
data.isnull().sum()
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %%
data['Happiness Score'].hist(grid=False)
plt.title("Happiness_score")
plt.show()

# %%
data['Happiness Score'].value_counts()
# Out:
# 5.192    2
# 7.587    1
# 4.686    1
# 4.839    1
# 4.800    1
#         ..
# 5.855    1
# 5.848    1
# 5.833    1
# 5.828    1
# 2.839    1
# Name: Happiness Score, Length: 157, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
LE =LabelEncoder()
data["Happiness Score"]=LE.fit_transform(data["Happiness Score"])

# %%
LE.inverse_transform([1,0])
# Out:
# array([2.905, 2.839])

# %%
LE.inverse_transform([0,1])
# Out:
# array([2.839, 2.905])

# %%
data['Happiness Score'].value_counts()
# Out:
# 75     2
# 156    1
# 48     1
# 55     1
# 54     1
#       ..
# 103    1
# 102    1
# 101    1
# 100    1
# 0      1
# Name: Happiness Score, Length: 157, dtype: int64

# %%
data.corr()
# Out:
#                                Happiness Rank  Happiness Score  \
# Happiness Rank                       1.000000        -0.999985
# Happiness Score                     -0.999985         1.000000
# Standard Error                       0.158516        -0.158201
# Economy (GDP per Capita)            -0.785267         0.785211
# Family                              -0.733644         0.733899
# Health (Life Expectancy)            -0.735613         0.735642
# Freedom                             -0.556886         0.557051
# Trust (Government Corruption)       -0.372315         0.372752
# Generosity                          -0.160142         0.160446
# Dystopia Residual                   -0.521999         0.522339
#
#                                Standard Error  Economy (GDP per Capita)  \
# Happiness Rank                       0.158516                 -0.785267
# Happiness Score                     -0.158201                  0.785211
# ...

# %%
corr_matrix =data.corr()
corr_matrix['Happiness Score'].sort_values(ascending= False )
# Out:
# Happiness Score                  1.000000
# Economy (GDP per Capita)         0.785211
# Health (Life Expectancy)         0.735642
# Family                           0.733899
# Freedom                          0.557051
# Dystopia Residual                0.522339
# Trust (Government Corruption)    0.372752
# Generosity                       0.160446
# Standard Error                  -0.158201
# Happiness Rank                  -0.999985
# Name: Happiness Score, dtype: float64

# %%
data.plot(kind='density', subplots= True ,layout=(6,11) ,sharex=False ,legend=False , fontsize=1 , figsize=(18,12))
plt.show()
